# %% [markdown]
# <a href="https://colab.research.google.com/github/S10955015/bigdata/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
NBA1819 <- fetch_NBAPlayerStatistics("18-19")

# %%
NBA1819order <- NBA1819[order(NBA1819$GamesPlayed,decreasing = T),]
NBA1819order[1:20]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 5   NBA    Bam Adebayo      MIA  C        82          1908
# 40  NBA    Bradley Beal     WAS  SG       82          3025
# 45  NBA    Deandre' Bembry  ATL  SF       82          1930
# 66  NBA    Mikal Bridges    PHO  SF       82          2418
# 87  NBA    Ke Caldwell-pope LAL  SG       82          2031
# 169 NBA    Bryn Forbes      SAN  SG       82          2288
# 186 NBA    Gilgeous-alexand LAC  PG       82          2174
# 208 NBA    Montrezl Harrell LAC  PF       82          2158
# 212 NBA    Tobias Harris    PHI  PF       82          2847
# 224 NBA    Buddy Hield      SAC  SG       82          2614
# 231 NBA    Justin Holiday   MEM  SG       82          2608
# 246 NBA    Joe Ingles       UTA  SF       82          2564
# 257 NBA    Reggie Jackson   DET  PG       82          2284
# 277 NBA    Cory Joseph      IND  PG       82          2061
# 350 NBA    Patty Mills      SAN  PG       82          1908
# ...

# %%
subset(NBA1819,Position=="PF")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 8   NBA    Lamarcu Aldridge SAN  PF       81          2689
# 13  NBA    Al-farouq Aminu  POR  PF       81          2289
# 16  NBA    Ryan Anderson    MIA  PF       25           321
# 18  NBA    Gi Antetokounmpo MIL  PF       72          2358
# 19  NBA    Ko Antetokounmpo DAL  PF        2            11
# 20  NBA    Carmelo Anthony  HOU  PF       10           294
# 27  NBA    Marvin Bagley    SAC  PF       62          1563
# 44  NBA    Jordan Bell      GSW  PF       67           790
# 46  NBA    Dragan Bender    PHO  PF       46           827
# 52  NBA    Nemanja Bjelica  SAC  PF       77          1793
# 59  NBA    Jonah Bolden     PHI  PF       44           641
# 62  NBA    Chris Boucher    TOR  PF       28           165
# 93  NBA    Wendell Carter   CHI  PF       44          1110
# 99  NBA    Tyler Cavanaugh  UTA  PF       11            41
# 104 NBA    Marquese Chriss  CLE  PF       43           498
# ...

# %%
NBA1819[grepl("Ray",NBA1819$Name),]
# Out:
#     League Name           Team Position GamesPlayed TotalMinutesPlayed
# 165 NBA    Raymond Felton OKL  PG       32          378
# 460 NBA    Ray Spalding   PHO  PF       14          148
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 165 55             135                 20         61              ⋯ 10
# 460 25              47                  0          3              ⋯  9
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 165 14        6      29            0                 142         0
# 460  9        8      23            0                  54         0
#     Ejections FlagrantFouls GamesStarted
# 165 0         0             0
# 460 0         0             3

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
NBA1819 <- fetch_NBAPlayerStatistics("18-19")
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1819)
# Out:
# plot without title

# %%
qplot(TotalPoints, data = NBA1819, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
df <- data.frame(gp = factor(rep(letters[1:3], each = 10)), y = rnorm(30))
ggplot(df, aes(x = gp, y = y)) +geom_boxplot()
# Out:
# plot without title

# %%
df$z<-df$y+rnorm(30)
ggplot(df, aes(x = z, y = y))+geom_point()+facet_grid(gp~.)
# Out:
# plot without title
